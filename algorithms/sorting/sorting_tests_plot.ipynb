# %%
import pandas as pd

# %%
df = pd.read_csv('../../docs/data/Sorting.csv')

# %%
df.set_index('Data_length').plot(
    figsize=(21, 13), title='Algorithms speed', xlabel='Data length', ylabel='Time in seconds',
    fontsize=10, colormap='rainbow')
# Out:
# <AxesSubplot:title={'center':'Algorithms speed'}, xlabel='Data length', ylabel='Time in seconds'>

# %%
df
# Out:
#    Data_length  quick_sort  shell_sort  merge_sort  insertion_sort  \
# 0           10    0.000887    0.000274    0.000612        0.000146
# 1          100    0.007227    0.004298    0.006955        0.013103
# 2         1000    0.072050    0.084048    0.098025        1.168558
# 3        10000    0.478295    1.554992    1.618297      121.332705
#
#    selection_sort      bubble
# 0        0.000221    0.000279
# 1        0.013090    0.014656
# 2        1.140543    1.354198
# 3      116.290301  141.536374

# %%
df5 = pd.read_csv('../../docs/data/Sorting5.csv')
df5.set_index('Data_length').plot(
    figsize=(21, 13), title='Algorithms speed', xlabel='Data length', ylabel='Time in seconds',
    fontsize=10, colormap='rainbow')
# Out:
# <AxesSubplot:title={'center':'Algorithms speed'}, xlabel='Data length', ylabel='Time in seconds'>

# %%
df5
# Out:
#    Data_length  quick_sort  shell_sort  merge_sort  insertion_sort  \
# 0           10    0.000618    0.000173    0.000500        0.000149
# 1          100    0.007212    0.003879    0.007221        0.011132
# 2         1000    0.069869    0.089557    0.103841        1.283601
# 3        10000    0.471554    1.382084    1.684814      132.488818
# 4       100000    4.054206   20.924585   63.237327    13263.137432
#
#    selection_sort        bubble
# 0        0.000235      0.000239
# 1        0.012317      0.014499
# 2        1.313403      1.445307
# 3      119.557935    153.612998
# 4    12579.450848  15546.615501
