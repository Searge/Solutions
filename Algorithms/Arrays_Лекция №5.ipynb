# %% [markdown]
# # Массивы (тип: list)
#
# `A -->` \[| 1 | 2 | 3 | 4 | 5 |]

# %%
A = [1, 2, 3, 4, 5]

for x in A:
    print(x)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
for x in A:
    print(x, type(x))
    x += 1
    print(x)
# Out:
# 1 <class 'int'>
# 2
# 2 <class 'int'>
# 3
# 3 <class 'int'>
# 4
# 4 <class 'int'>
# 5
# 5 <class 'int'>
# 6

# %%
for k in range(5):
    A[k] = A[k] * A[k]
    
print(A)
# Out:
# [1, 4, 9, 16, 25]

# %%
B = [0] * 1000
top = 0
x = int(input())
while x != 0:
    B[top] = x
    top += 1
    x = int(input())
# Out:
# 3
# 4
# 5
# 1
# 6
# 2
# 2
# 7
# 9
# 8
# 3
# 7
# 3
# 2
# 0

# %%
for k in range(13, -1, -1):
    print(B[k])
# Out:
# 2
# 3
# 7
# 3
# 8
# 9
# 7
# 2
# 2
# 6
# 1
# 5
# 4
# 3

# %%
N = int(input())

A = [0]*N
B = [0]*N

for k in range(N):
    A[k] = int(input())
# Out:
# 6
# 2
# 4
# 5
# 6
# 7
# 8

# %%
print(A, B)
# Out:
# [2, 4, 5, 6, 7, 8] [0, 0, 0, 0, 0, 0]

# %%
# copying from A to B

for k in range(N):
    B[k] = A[k]
    
print(A, B)
# Out:
# [2, 4, 5, 6, 7, 8] [2, 4, 5, 6, 7, 8]

# %%
C = A
print(C)
# Out:
# [2, 4, 5, 6, 7, 8]

# %%
C
# Out:
# [2, 4, 5, 6, 7, 8]

# %%
type(C)
# Out:
# list

# %%
# making new list from A
C = list(A)

# %%
type(C)
# Out:
# list

# %% [markdown]
# ## Алгоритмы

# %%
def array_search(A:list, N:int, x:int):
    """ Осуществляет поиск числа x в массиве A
        от 0 до N-1 индекса влючительно.
        Возвращает идекс элемента x в массиве A.
        Или -1, если такого нет.
        Если в массиве несколько одинаковых елементов,
        равных x, то вернуть первого по счёту.
    """
    for k in range(N):
        if A[k] == x:
            return k
    return -1

def test_array_search():
    A1 = [1, 2, 3, 4, 5]
    m = array_search(A1, 5, 8)
    if m == -1:
        print('#test1 - ok')
    else:
        print('#test1 - fail')
        
    A2 = [-1, -2, -3, -4, -5]
    m = array_search(A2, 5, -3)
    if m == 2:
        print('#test2 - ok')
    else:
        print('#test2 - fail')
        
    A3 = [10, 20, 30, 10, 10]
    m = array_search(A3, 5, 10)
    if m == 0:
        print('#test3 - ok')
    else:
        print('#test3 - fail')
        
test_array_search()
# Out:
# #test1 - ok
# #test2 - ok
# #test3 - ok

# %%
def invert_array(A:list, N:int):
    """ Обращение массива (поворот задом-наперёд)
        в рамках индексов от 0 до N-1
    """
    for k in range (N//2):
        A[k], A[N-1-k] = A[N-1-k], A[k]

def test_invert_array():
    A1 = [1, 2, 3, 4, 5]
    print(A1)
    invert_array(A1, 5)
    print(A1)
    if A1 == [5, 4, 3, 2, 1]:
        print('#test1 - ok')
    else:
        print('#test1 - fail')
        
    A2 = [0, 0, 0, 0, 0, 0, 0, 10]
    print(A2)
    invert_array(A2, 8)
    print(A2)
    if A2 == [10, 0, 0, 0, 0, 0, 0, 0]:
        print('#test2 - ok')
    else:
        print('#test2 - fail')
        
test_invert_array()
# Out:
# [1, 2, 3, 4, 5]
# [5, 4, 3, 2, 1]
# #test1 - ok
# [0, 0, 0, 0, 0, 0, 0, 10]
# [10, 0, 0, 0, 0, 0, 0, 0]
# #test2 - ok

# %% [markdown]
# ## Циклический сдвиг
#
# Бітовий зсув - зміна позицій бітів у слові на одну і ту ж величину.
#
# Більшість комп'ютерів не можуть напряму адресувати біти, які містяться групами по 8, 16, 32 або 64 бітів у словах. Для забезпечення роботи з бітами існує безліч машинних інструкцій, що включають різні типи зрушень. Всі зрушення схожі один на одного поведінкою середніх бітів, які просто зсуваються вліво або вправо на певну величину. Однак, поведінка крайніх бітів, які йдуть з слова та які з'являються в слові, залежить від типу зсуву.
# В електроніці бітові зрушення здійснюються в регістрах зсуву.
#
# https://uk.wikipedia.org/wiki/Бітовий_зсув

# %%
A
# Out:
# [2, 4, 5, 6, 7, 8]

# %%
tmp = A[0]

for k in range(N-1):
    A[k] = A[k+1]
    A[N-1] = tmp
print(A)
# Out:
# [4, 5, 6, 7, 2, 2]

# %%
tmp = A[0]

for k in range(N-1):
    A[k] = A[k+1]

A[N-1] = tmp
print(A)
# Out:
# [5, 6, 7, 2, 2, 4]

# %%
tmp = A[N-1]

for k in range(N-2, -1, -1):
    A[k+1] = A[k]
    
A[0] = tmp
print(A)
# Out:
# [4, 5, 6, 7, 2, 2]

# %% [markdown]
# ## Решето Эратосфена
#
# Якщо потрібно знайти всі прості числа менші за певне число N, виписуються всі числа від $1$ до $N$.
# 1. Перше просте число - два. Викреслимо всі числа більші двох, які діляться на два $(4, 6, 8 …)$.
# 1. Наступне число, яке залишилося незакресленим (три), є простим. Викреслюємо всі числа більші трьох та кратні трьом $(6, 9 …)$.
# 1. Наступне незакреслене число (п'ять) є простим. Викреслимо всі числа більші п'яти та кратні п'яти $(10, 15, 20, 25 …)$.
# 1. Повторюємо операцію поки не буде досягнуто число $N$:
# 1. Наступне незакреслене число є простим.
#     - Викреслимо всі числа більші нього та кратні йому.
#
# Числа, які залишилися незакресленими після цієї процедури - прості
# https://uk.wikipedia.org/wiki/Решето_Ератосфена

# %%
A = [True] * N
A[0] = A[1] = False

for k in range(2, N):
    if A[k]: # == True
        for m in range(2 * k, N, k):
            A[m] = False
            
print(A)
# Out:
# [False, False, True, True, False, True]

# %%
for k in range(N):
    print(k, '-', 'простое' if A[k] else 'составное')
# Out:
# 0 - составное
# 1 - составное
# 2 - простое
# 3 - простое
# 4 - составное
# 5 - простое
