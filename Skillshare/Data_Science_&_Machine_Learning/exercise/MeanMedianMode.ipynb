# %% [markdown]
# # Mean, Median, Mode, and introducing NumPy
#
# ## Mean vs. Median
#
# Let's create some fake income data, centered around 27,000 with a normal distribution and standard deviation of 15,000, with 10,000 data points. (We'll discuss those terms more later, if you're not familiar with them.)
#
# Then, compute the mean (average) - it should be close to 27,000:
#
# > ### [Нормальний розподіл](https://uk.wikipedia.org/wiki/Нормальний_розподіл)
# > Нормальний розподіл — розподіл ймовірностей випадкової величини, що характеризується густиною ймовірності де — математичне сподівання, — дисперсія випадкової величини. Параметр також відомий, як стандартне відхилення. Розподіл із $μ = 0$ та $σ 2 = 1$ називають стандартним нормальним розподілом.

# %%
import numpy as np

# list of numbers ↓
incomes = np.random.normal(27000, 15000, 10000)
# centered 27k, standart deviation 15k & 10k data points
# average of data points is:
np.mean(incomes)
# Out:
# 26822.208231763674

# %% [markdown]
# We can segment the income data into 50 buckets, and plot it as a histogram:

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.hist(incomes, 50) 
# 50 different buckets
plt.show()

# %% [markdown]
# Now compute the median - since we have a nice, even distribution it too should be close to 27,000:

# %%
np.median(incomes)
# Out:
# 26692.189734133673

# %% [markdown]
# Now we'll add Donald Trump into the mix. Darn income inequality!

# %%
incomes = np.append(incomes, [1000_000_000])
# stick in some dude with a billion dollars

# %% [markdown]
# The _median_ won't change much, **but the mean does**:

# %%
np.median(incomes)
# Out:
# 26693.013862066044

# %%
np.mean(incomes)
# Out:
# 126809.52727903577

# %%
incomes
# Out:
# array([3.43406701e+04, 1.78259997e+04, 5.70076695e+04, ...,
#        6.04260069e+04, 1.75632795e+04, 1.00000000e+09])

# %% [markdown]
# ## Mode
#
# Next, let's generate some fake age data for 500 people:

# %%
# Generate bunch of 500 random integers in range between 18 & 90
ages = np.random.randint(18, high=90, size=500)
ages
# Out:
# array([65, 75, 27, 70, 67, 24, 76, 40, 35, 22, 53, 66, 32, 36, 87, 49, 65,
#        86, 69, 77, 55, 50, 28, 46, 60, 64, 62, 76, 78, 56, 87, 86, 29, 84,
#        84, 59, 27, 85, 29, 81, 55, 59, 70, 68, 82, 28, 79, 24, 65, 23, 19,
#        77, 88, 21, 39, 45, 23, 45, 72, 58, 60, 58, 22, 69, 35, 76, 26, 38,
#        25, 84, 76, 80, 37, 25, 88, 76, 21, 73, 25, 86, 54, 89, 24, 21, 58,
#        88, 81, 60, 27, 43, 81, 41, 20, 61, 62, 54, 61, 59, 76, 33, 55, 60,
#        27, 87, 40, 84, 71, 77, 51, 56, 18, 42, 42, 68, 75, 43, 80, 28, 32,
#        28, 35, 31, 42, 70, 25, 40, 70, 82, 37, 54, 66, 63, 41, 22, 50, 64,
#        79, 65, 83, 62, 26, 20, 77, 75, 54, 82, 44, 65, 20, 50, 51, 30, 25,
#        68, 78, 85, 38, 53, 65, 61, 39, 69, 67, 85, 19, 45, 57, 51, 56, 28,
#        62, 84, 84, 29, 34, 43, 59, 69, 70, 19, 32, 31, 83, 38, 83, 87, 42,
#        77, 24, 33, 22, 22, 29, 23, 27, 78, 85, 76, 49, 81, 83, 36, 48, 18,
#        72, 69, 66, 49, 82, 45, 32, 33, 58, 78, 47, 65, 40, 19, 69, 69, 71,
#        30, 51, 51, 79, 72, 57, 35, 41, 49, 32, 75, 61, 49, 83, 23, 65, 64,
#        67, 88, 49, 27, 62, 73, 83, 51, 83, 32, 37, 50, 39, 78, 79, 68, 44,
#        47, 75, 58, 35, 57, 48, 27, 28, 75, 18, 83, 22, 36, 83, 46, 53, 67,
#        75, 80, 69, 45, 38, 33, 74, 69, 55, 25, 66, 62, 49, 53, 59, 38, 44,
#        29, 45, 20, 83, 81, 73, 46, 20, 28, 59, 45, 48, 58, 18, 30, 57, 79,
#        75, 81, 76, 49, 33, 53, 22, 52, 38, 67, 26, 60, 85, 36, 70, 63, 38,
#        35, 45, 19, 73, 59, 67, 22, 19, 37, 42, 58, 34, 56, 29, 23, 64, 75,
#        54, 57, 86, 63, 60, 81, 83, 64, 28, 42, 85, 81, 31, 85, 52, 74, 82,
#        66, 40, 38, 48, 74, 48, 52, 28, 60, 41, 82, 43, 34, 53, 34, 52, 78,
#        22, 52, 38, 70, 36, 63, 25, 28, 57, 64, 43, 42, 34, 46, 80, 70, 21,
#        49, 24, 34, 18, 58, 77, 80, 87, 18, 26, 62, 31, 68, 49, 71, 37, 32,
#        57, 86, 46, 28, 21, 84, 46, 67, 83, 62, 27, 27, 68, 53, 38, 51, 50,
#        70, 86, 82, 47, 44, 78, 58, 73, 24, 75, 40, 60, 75, 85, 86, 32, 88,
#        31, 82, 41, 40, 57, 36, 56, 78, 87, 52, 30, 72, 41, 28, 75, 33, 54,
#        58, 23, 66, 69, 37, 53, 77, 47, 21, 89, 63, 74, 35, 67, 21, 82, 87,
#        85, 89, 59, 76, 41, 77, 59, 24, 59, 34, 65, 51, 36, 53, 24, 24, 39,
#        87, 28, 33, 18, 36, 73, 46])

# %%
from scipy import stats
stats.mode(ages)
# Out:
# ModeResult(mode=array([28]), count=array([13]))

# %% [markdown]
# * `mode=array([28])` — most common value
# * `count=array([13])` — count in array for 13 times

# %% [markdown]
# # Exercise: Mean & Median Customer Spend
#
# Here's some code that will generate some random e-commerce data; just an array of total amount spent per transaction. Select the code block, and hit "play" to execute it:

# %%
incomes_ex = np.random.normal(100.0, 20.0, 10000)

plt.hist(incomes_ex, 50)
plt.show()

# %% [markdown]
# Now, find the mean and median of this data. In the code block below, write your code, and see if your result makes sense:

# %% [markdown]
# This is pretty much the world's easiest assignment, but we're just trying to get your hands on iPython and writing code with numpy to get you comfortable with it.
#
# Try playing with the code above to generate different distributions of data, or add outliers to it to see their effect.
