# %% [markdown]
# # Standard Deviation and Variance

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
# As in previous file

incomes = np.random.normal(60.0, 12.0, 1000)

plt.hist(incomes, 50)
plt.show()

# %%
incomes.std()
# Out:
# 2.6510448850201795

# %%
incomes.var()
# Out:
# 7.0280389823916565
