# %% [markdown]
# # Standard Deviation and Variance

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
# As in previous file

incomes = np.random.normal(1696.0, 8000.0, 10000)

plt.hist(incomes, 50)
plt.show()

# %%
incomes.std()
# Out:
# 7942.44316615329

# %%
incomes.var()
# Out:
# 63082403.4475751
