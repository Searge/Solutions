# %% [markdown]
# # Oh My Py — канал про тайные возможности стандартной библиотеки Питона.
# - [ ]  https://t.me/ohmypy/4
#
# Тайные не потому, что кто-то их скрывает, конечно ツ
#
# Просто стандартная библиотека огромная! А разработчики часто не копают глубоко и изобретают велосипед вместо того, чтобы использовать готовое.
#
# ---
#
# ## Сделать превьюшку длинного текста
#
# Допустим, мы хотим получить превьюшку длинной статьи. Можно обрезать механически:

# %%
article = "Около двух месяцев назад породистый голубь по имени Френк постучался в стеклянные двери омской ветеринарной клиники"
article[:30]
# Out:
# 'Около двух месяцев назад пород'

# %% [markdown]
# Фраза оборвана посреди слова — это неуважение к читателю и к Френку.
#
# А можно воспользоваться функцией `textwrap.shorten()`:

# %%
import textwrap

textwrap.shorten(article, 30, placeholder="...")
# Out:
# 'Около двух месяцев назад...'

# %% [markdown]
# ## Отформатировать текст для консоли
#
# Если любите делать CLI-утилиты, модуль textwrap наверняка вам понравится.
#
# Он умеет перформатировать многострочный текст, чтобы длина строки не превышала N символов:

# %%
text = "Около двух месяцев назад породистый голубь по имени Френк постучался в стеклянные двери омской ветеринарной клиники"
formatted = textwrap.fill(text, width=20)
print(formatted)
# Out:
# Около двух месяцев
# назад породистый
# голубь по имени
# Френк постучался в
# стеклянные двери
# омской ветеринарной
# клиники

# %%
# Или добавить отступ, например для цитаты:

import textwrap
inspirational = "Цитаты простых людей:"
quote = "Откройте окно вообще дышать невозможно"
quote = textwrap.indent(quote, prefix="> ")
print(inspirational, quote, sep="\n")
# Out:
# Цитаты простых людей:
# > Откройте окно вообще дышать невозможно

# %% [markdown]
# ## Все слова с прописной буквы
#
# Допустим, запустили вы стартап. В автоматическом режиме собираете самые упоротые новости русскоязычных СМИ, вот такие:
#
# _Кот из Новокузнецка признан виновным в потопе_
#
# Автоматически же переводите их на английский, вот так:
#
# _Cat from Novokuznetsk found guilty in the flood_
#
# И ежедневно рассылаете подписчикам по всему миру.
#
# Всё хорошо, но знакомый эксперт из МГИМО подсказывает: в английском принято каждое слово в заголовке начинать с заглавной буквы. А у вас-то не так!
#
# Можно, конечно, бить заголовок по пробелам
# - через `.split()`, исправлять регистр
# - через `.capitalize()` и склеивать обратно
# - через `.join()`.
#
# Но есть способ лучше:

# %%
import string
header = "Cat from Novokuznetsk found guilty in the flood"
string.capwords(header)
# Out:
# 'Cat From Novokuznetsk Found Guilty In The Flood'

# %% [markdown]
# ## Простое сравнение с шаблоном
#
# Для проверки строки по шаблону обычно используют регулярные выражения и модуль re. Но иногда хочется что-нибудь попроще, пусть и не такое мощное — вроде `like` в SQL.
#
# Сравнить строку или список с шаблоном поможет модуль `fnmatch`:

# %%
import fnmatch
journal = [
  "10:00 Начался обычный день в омской ветклинике",
  "10:30 Голубь Френк постучался в стеклянные двери",
  "10:50 Лисица Клер поскреблась в окно",
  "11:10 Попугай Питер проник через вентиляцию",
  "11:11 Клер попыталась сожрать Френка и Питера",
  "11:25 Осьминог Пауль всплыл в мужском туалете",
]

fnmatch.filter(journal, "*Френк*")
# Out:
# ['10:30 Голубь Френк постучался в стеклянные двери',
#  '11:11 Клер попыталась сожрать Френка и Питера']

# %%
fnmatch.fnmatch("frank", "f???k")
# Out:
# True

# %% [markdown]
# > Под капотом используются регулярки, так что всегда можно конвертировать шаблон в регулярное выражение:

# %%
fnmatch.translate("*Френк*")
# Out:
# '(?s:.*\\Ф\\р\\е\\н\\к.*)\\Z'

# %% [markdown]
# ## Сравнить строки на похожесть
#
# Помните ваш стартап с самыми актуальными новостями дня? Кажется, у него появился конкурент — он нагло крадёт ваши аутентичные новости, рерайтит их, и рассылает ничего не подозревающим клиентам, подрывая вашу репутацию.
#
# Судите сами, вот ваши новости:

# %%
genuine = [
  "«Братец-хлеб» из Китая носит плащ и корону из булочек, чтобы кормить чаек",
  "Мясо гигантских тараканов станет вкусной и недорогой альтернативой говядине",
  "Скандал в ботаническом саду: 10 миллионов рублей ушло на зарплату кактусам",
]

# %% [markdown]
# А вот новости жалкого подражателя:

# %%
plagiary = [
  "Китайский хлебный братец кормит чаек плащом и короной из булочек",
  "Гигантское мясо тараканов станет говядине недорогой и вкусной альтернативой",
  "Зарплата кактусов в ботаническом саду составила 10 скандальных миллионов рублей",
]

# %% [markdown]
# Нужны какие-то основания для судебного иска, и нужны быстро. Хорошо, что в стандартной библиотеке Питона есть модуль `difflib`. Сделаем на нём функцию сравнения:

# %%
import difflib

def similarity(s1, s2):
  normalized1 = s1.lower()
  normalized2 = s2.lower()
  matcher = difflib.SequenceMatcher(None, normalized1, normalized2)
  return matcher.ratio()

# %%
similarity(genuine[0], plagiary[0])
# Out:
# 0.5109489051094891

# %%
similarity(genuine[1], plagiary[1])
# Out:
# 0.6933333333333334

# %%
similarity(genuine[2], plagiary[2])
# Out:
# 0.5490196078431373

# %% [markdown]
# ### _АГА!!!_
#
# — $51\%$, $69\%$ и $55\%$ похожести!
#
# _Всё ясно_, какие ещё нужны доказательства.

# %% [markdown]
# ## Напечатать развесистую структуру данных в кратком виде
#
# Наверняка вы знаете про функции `pprint.pprint` и `pprint.pformat`, который красиво форматируют разные коллекции и словари.
#
# У них есть замечательный опциональный параметр depth, который ограничивает уровень вложенности при форматировании. Он здорово помогает, если хочется получить общее представление о данных, не сильно вникая в детали.
#
# Например, запросили вы апишечку и получили в ответ развесистый словарь:

# %%
import requests

rating = requests.get("https://raw.githubusercontent.com/factbook/factbook.json/master/europe/be.json").json()

# %% [markdown]
# Заглянем в него, не погружаясь в детали:

# %%
import pprint
pprint.pprint(rating, depth=3)
# Out:
# {'Communications': {'Broadcast media': {'text': 'a segmented market with the '
#                                                 'three major communities '
#                                                 '(Flemish, French, and '
#                                                 'German-speaking) each having '
#                                                 'responsibility for their own '
#                                                 'broadcast media; multiple TV '
#                                                 'channels exist for each '
#                                                 'community; additionally, in '
#                                                 'excess of 90% of households '
#                                                 'are connected (2007)'},
#                     'Internet country code': {'text': '.be'},
#                     'Internet users': {'percent of population': {...},
#                                        'total': {...}},
#                     'Telephone system': {'domestic': {...},
#                                          'general assessment': {...},
#                                          'international': {...}},
#                     'Telephones - fixed lines': {'subscriptions per 100 inhabitants': {'text': '40 '
#                                                                                                '(July '
#                                                                                                '2015 '
#                                                                                                'est.)'},
#                                                  'total subscriptions': {...}},
#                     'Telephones - mobile cellular': {'subscriptions per 100 inhabitants': {'text': '114 '
#                                                                                                    '(July '
#                                                                                                    '2015 '
#                                                                                                    'est.)'},
#                                                      'total': {...}}},
#  'Economy': {'Agriculture - products': {'text': 'sugar beets, fresh '
#                                                 'vegetables, fruits, grain, '
#                                                 'tobacco; beef, veal, pork, '
#                                                 'milk'},
#              'Budget': {'expenditures': {...}, 'revenues': {...}},
#              'Budget surplus (+) or deficit (-)': {'text': '-2.7% of GDP (2016 '
#                                                            'est.)'},
#              'Central bank discount rate': {'note': {...},
#                                             'text': '0.05% (31 December 2013) '
#                                                     '++ 0.3% (31 December '
#                                                     '2010)'},
#              'Commercial bank prime lending rate': {'text': '2.5% (31 December '
#                                                             '2016 est.) ++ '
#                                                             '2.46% (31 '
#                                                             'December 2015 '
#                                                             'est.)'},
#              'Current account balance': {'text': '$585 million (2016 est.) ++ '
#                                                  '-$155 million (2015 est.)'},
#              'Debt - external': {'text': '$1.281 trillion (31 March 2016 est.) '
#                                          '++ $1.214 trillion (31 March 2015 '
#                                          'est.)'},
#              'Distribution of family income - Gini index': {'text': '25.9 '
#                                                                     '(2013 '
#                                                                     'est.) ++ '
#                                                                     '28.7 '
#                                                                     '(1996)'},
#              'Economy - overview': {'text': 'This modern, open, and '
#                                             'private-enterprise-based economy '
#                                             'has capitalized on its central '
#                                             'geographic location, highly '
#                                             'developed transport network, and '
#                                             'diversified industrial and '
#                                             'commercial base. Industry is '
#                                             'concentrated mainly in the more '
#                                             'heavily-populated region of '
#                                             'Flanders in the north. With few '
#                                             'natural resources, Belgium '
#                                             'imports substantial quantities of '
#                                             'raw materials and exports a large '
#                                             'volume of manufactures, making '
#                                             'its economy vulnerable to shifts '
#                                             'in foreign demand, particularly '
#                                             'with Belgium’s EU trade partners. '
#                                             'Roughly three-quarters of '
#                                             "Belgium's trade is with other EU "
#                                             'countries. ++  ++ In 2015, '
#                                             'Belgian GDP grew by 1.4%, the '
#                                             'unemployment rate stabilized at '
#                                             '8.6%, and the budget deficit was '
#                                             '2.7% of GDP. Prime Minister '
#                                             "Charles MICHEL's center-right "
#                                             'government has pledged to further '
#                                             'reduce the deficit in response to '
#                                             "EU pressure to reduce Belgium's "
#                                             'high public debt, which remains '
#                                             'above 100% of GDP, but such '
#                                             'efforts could also dampen '
#                                             'economic growth. In addition to '
#                                             'restrained public spending, low '
#                                             'wage growth and high unemployment '
#                                             'promise to curtail a more robust '
#                                             'recovery in private consumption. '
#                                             '++  ++ The government has pledged '
#                                             'to pursue a reform program to '
#                                             'improve Belgium’s '
#                                             'competitiveness, including '
#                                             'changes to tax policy, labor '
#                                             'market rules, and welfare '
#                                             'benefits. These changes risk '
#                                             'worsening tensions with trade '
#                                             'unions and triggering extended '
#                                             'strikes.'},
#              'Exchange rates': {'text': 'euros (EUR) per US dollar - ++ 0.9214 '
#                                         '(2016 est.) ++ 0.885 (2015 est.) ++ '
#                                         '0.885 (2014 est.) ++ 0.7634 (2013 '
#                                         'est.) ++ 0.78 (2012 est.)'},
#              'Exports': {'text': '$250.8 billion (2016 est.) ++ $259.9 billion '
#                                  '(2015 est.)'},
#              'Exports - commodities': {'text': 'chemicals, machinery and '
#                                                'equipment, finished diamonds, '
#                                                'metals and metal products, '
#                                                'foodstuffs'},
#              'Exports - partners': {'text': 'Germany 16.9%, France 15.5%, '
#                                             'Netherlands 11.4%, UK 8.8%, US '
#                                             '6%, Italy 5% (2015)'},
#              'Fiscal year': {'text': 'calendar year'},
#              'GDP (official exchange rate)': {'text': '$470.2 billion (2015 '
#                                                       'est.)'},
#              'GDP (purchasing power parity)': {'note': {...},
#                                                'text': '$508.6 billion (2016 '
#                                                        'est.) ++ $501.4 '
#                                                        'billion (2015 est.) ++ '
#                                                        '$494.6 billion (2014 '
#                                                        'est.)'},
#              'GDP - composition, by end use': {'exports of goods and services': {'text': '83.1%'},
#                                                'government consumption': {...},
#                                                'household consumption': {...},
#                                                'imports of goods and services': {'text': '-82.1% '
#                                                                                          '(2016 '
#                                                                                          'est.)'},
#                                                'investment in fixed capital': {'text': '23.3%'},
#                                                'investment in inventories': {'text': '-0.1%'}},
#              'GDP - composition, by sector of origin': {'agriculture': {...},
#                                                         'industry': {...},
#                                                         'services': {...}},
#              'GDP - per capita (PPP)': {'note': {...},
#                                         'text': '$44,900 (2016 est.) ++ '
#                                                 '$44,700 (2015 est.) ++ '
#                                                 '$44,100 (2014 est.)'},
#              'GDP - real growth rate': {'text': '1.4% (2016 est.) ++ 1.4% '
#                                                 '(2015 est.) ++ 1.3% (2014 '
#                                                 'est.)'},
#              'Gross national saving': {'text': '23.8% of GDP (2016 est.) ++ '
#                                                '22.6% of GDP (2015 est.) ++ '
#                                                '22.8% of GDP (2014 est.)'},
#              'Household income or consumption by percentage share': {'highest 10%': {'text': '28.4% '
#                                                                                              '(2006)'},
#                                                                      'lowest 10%': {'text': '3.4%'}},
#              'Imports': {'text': '$251.7 billion (2016 est.) ++ $259.6 billion '
#                                  '(2015 est.)'},
#              'Imports - commodities': {'text': 'raw materials, machinery and '
#                                                'equipment, chemicals, raw '
#                                                'diamonds, pharmaceuticals, '
#                                                'foodstuffs, transportation '
#                                                'equipment, oil products'},
#              'Imports - partners': {'text': 'Netherlands 16.7%, Germany 12.7%, '
#                                             'France 9.6%, US 8.7%, UK 5.1%, '
#                                             'Ireland 4.7%, China 4.3% (2015)'},
#              'Industrial production growth rate': {'text': '1.5% (2016 est.)'},
#              'Industries': {'text': 'engineering and metal products, motor '
#                                     'vehicle assembly, transportation '
#                                     'equipment, scientific instruments, '
#                                     'processed food and beverages, chemicals, '
#                                     'base metals, textiles, glass, petroleum'},
#              'Inflation rate (consumer prices)': {'text': '1.6% (2016 est.) ++ '
#                                                           '0.6% (2015 est.)'},
#              'Labor force': {'text': '5.272 million (2016 est.)'},
#              'Labor force - by occupation': {'agriculture': {...},
#                                              'industry': {...},
#                                              'services': {...}},
#              'Market value of publicly traded shares': {'text': '$414.6 '
#                                                                 'billion (31 '
#                                                                 'December 2015 '
#                                                                 'est.) ++ '
#                                                                 '$378.5 '
#                                                                 'billion (31 '
#                                                                 'December 2014 '
#                                                                 'est.) ++ '
#                                                                 '$374.3 '
#                                                                 'billion (31 '
#                                                                 'December 2013 '
#                                                                 'est.)'},
#              'Population below poverty line': {'text': '15.1% (2013 est.)'},
#              'Public debt': {'note': {...},
#                              'text': '106.7% of GDP (2016 est.) ++ 106.1% of '
#                                      'GDP (2015 est.)'},
#              'Reserves of foreign exchange and gold': {'text': '$24.1 billion '
#                                                                '(31 December '
#                                                                '2015 est.) ++ '
#                                                                '$25.4 billion '
#                                                                '(31 December '
#                                                                '2014 est.)'},
#              'Stock of broad money': {'text': '$606.9 billion (31 December '
#                                               '2014 est.) ++ $630.9 billion '
#                                               '(31 December 2013 est.)'},
#              'Stock of direct foreign investment - abroad': {'text': '$1.01 '
#                                                                      'trillion '
#                                                                      '(31 '
#                                                                      'December '
#                                                                      '2016 '
#                                                                      'est.) ++ '
#                                                                      '$1.01 '
#                                                                      'trillion '
#                                                                      '(31 '
#                                                                      'December '
#                                                                      '2015 '
#                                                                      'est.)'},
#              'Stock of direct foreign investment - at home': {'text': '$1.045 '
#                                                                       'trillion '
#                                                                       '(31 '
#                                                                       'December '
#                                                                       '2016 '
#                                                                       'est.) '
#                                                                       '++ '
#                                                                       '$1.034 '
#                                                                       'trillion '
#                                                                       '(31 '
#                                                                       'December '
#                                                                       '2015 '
#                                                                       'est.)'},
#              'Stock of domestic credit': {'text': '$646.6 billion (31 December '
#                                                   '2016 est.) ++ $660.8 '
#                                                   'billion (31 December 2015 '
#                                                   'est.)'},
#              'Stock of narrow money': {'note': {...},
#                                        'text': '$193 billion (31 December 2016 '
#                                                'est.) ++ $181.5 billion (31 '
#                                                'December 2015 est.)'},
#              'Taxes and other revenues': {'text': '49.4% of GDP (2016 est.)'},
#              'Unemployment rate': {'text': '8.4% (2016 est.) ++ 8.5% (2015 '
#                                            'est.)'}},
#  'Energy': {'Carbon dioxide emissions from consumption of energy': {'text': '141 '
#                                                                             'million '
#                                                                             'Mt '
#                                                                             '(2013 '
#                                                                             'est.)'},
#             'Crude oil - exports': {'text': '73,090 bbl/day (2015 est.)'},
#             'Crude oil - imports': {'text': '715,000 bbl/day (2015 est.)'},
#             'Crude oil - production': {'text': '0 bbl/day (2015 est.)'},
#             'Crude oil - proved reserves': {'text': '0 bbl (1 January 2016 '
#                                                     'es)'},
#             'Electricity - consumption': {'text': '81 billion kWh (2014 est.)'},
#             'Electricity - exports': {'text': '4.2 billion kWh (2014 est.)'},
#             'Electricity - from fossil fuels': {'text': '39.3% of total '
#                                                         'installed capacity '
#                                                         '(2012 est.)'},
#             'Electricity - from hydroelectric plants': {'text': '0.6% of total '
#                                                                 'installed '
#                                                                 'capacity '
#                                                                 '(2012 est.)'},
#             'Electricity - from nuclear fuels': {'text': '28.2% of total '
#                                                          'installed capacity '
#                                                          '(2012 est.)'},
#             'Electricity - from other renewable sources': {'text': '25.7% of '
#                                                                    'total '
#                                                                    'installed '
#                                                                    'capacity '
#                                                                    '(2012 '
#                                                                    'est.)'},
#             'Electricity - imports': {'text': '22 billion kWh (2014 est.)'},
#             'Electricity - installed generating capacity': {'text': '21 '
#                                                                     'million '
#                                                                     'kW (2014 '
#                                                                     'est.)'},
#             'Electricity - production': {'text': '68 billion kWh (2014 est.)'},
#             'Natural gas - consumption': {'text': '15.78 billion cu m (2014 '
#                                                   'est.)'},
#             'Natural gas - exports': {'text': '848 million cu m (2014 est.)'},
#             'Natural gas - imports': {'text': '16.82 billion cu m (2014 est.)'},
#             'Natural gas - production': {'text': '0 cu m (2014 est.)'},
#             'Natural gas - proved reserves': {'text': '0 cu m (1 January 2014 '
#                                                       'es)'},
#             'Refined petroleum products - consumption': {'text': '647,800 '
#                                                                  'bbl/day '
#                                                                  '(2015 est.)'},
#             'Refined petroleum products - exports': {'text': '535,700 bbl/day '
#                                                              '(2015 est.)'},
#             'Refined petroleum products - imports': {'text': '547,700 bbl/day '
#                                                              '(2015 est.)'},
#             'Refined petroleum products - production': {'text': '730,200 '
#                                                                 'bbl/day (2015 '
#                                                                 'est.)'}},
#  'Geography': {'Area': {'land': {...}, 'total': {...}, 'water': {...}},
#                'Area - comparative': {'text': 'about the size of Maryland'},
#                'Climate': {'text': 'temperate; mild winters, cool summers; '
#                                    'rainy, humid, cloudy'},
#                'Coastline': {'text': '66.5 km'},
#                'Elevation': {'elevation extremes': {...},
#                              'mean elevation': {...}},
#                'Environment - current issues': {'text': 'intense pressures '
#                                                         'from human '
#                                                         'activities: '
#                                                         'urbanization, dense '
#                                                         'transportation '
#                                                         'network, industry, '
#                                                         'extensive animal '
#                                                         'breeding and crop '
#                                                         'cultivation; air and '
#                                                         'water pollution also '
#                                                         'have repercussions '
#                                                         'for neighboring '
#                                                         'countries'},
#                'Environment - international agreements': {'party to': {...},
#                                                           'signed, but not ratified': {'text': 'none '
#                                                                                                'of '
#                                                                                                'the '
#                                                                                                'selected '
#                                                                                                'agreements'}},
#                'Geographic coordinates': {'text': '50 50 N, 4 00 E'},
#                'Geography - note': {'text': 'crossroads of Western Europe; '
#                                             'most West European capitals are '
#                                             'within 1,000 km of Brussels, the '
#                                             'seat of both the European Union '
#                                             'and NATO'},
#                'Irrigated land': {'text': '230 sq km (2012)'},
#                'Land boundaries': {'border countries': {...}, 'total': {...}},
#                'Land use': {'agricultural land': {...},
#                             'forest': {...},
#                             'other': {...}},
#                'Location': {'text': 'Western Europe, bordering the North Sea, '
#                                     'between France and the Netherlands'},
#                'Map references': {'text': 'Europe'},
#                'Maritime claims': {'contiguous zone': {...},
#                                    'continental shelf': {...},
#                                    'exclusive economic zone': {...},
#                                    'territorial sea': {...}},
#                'Natural hazards': {'text': 'flooding is a threat along rivers '
#                                            'and in areas of reclaimed coastal '
#                                            'land, protected from the sea by '
#                                            'concrete dikes'},
#                'Natural resources': {'text': 'construction materials, silica '
#                                              'sand, carbonates, arable land'},
#                'Population - distribution': {'text': 'most of the population '
#                                                      'concentrated in the '
#                                                      'northern two-thirds of '
#                                                      'the country; the '
#                                                      'southeast is more thinly '
#                                                      'populated; considered to '
#                                                      'have one of the highest '
#                                                      'population densities in '
#                                                      'the world; approximately '
#                                                      '97% live in urban areas'},
#                'Terrain': {'text': 'flat coastal plains in northwest, central '
#                                    'rolling hills, rugged mountains of '
#                                    'Ardennes Forest in southeast'}},
#  'Government': {'Administrative divisions': {'note': {...},
#                                              'text': '3 regions (French: '
#                                                      'regions, singular - '
#                                                      'region; Dutch: gewesten, '
#                                                      'singular - gewest); '
#                                                      'Brussels-Capital Region, '
#                                                      'also known as Brussels '
#                                                      'Hoofdstedelijk Gewest '
#                                                      '(Dutch), Region de '
#                                                      'Bruxelles-Capitale '
#                                                      '(French long form), '
#                                                      'Bruxelles-Capitale '
#                                                      '(French short form); '
#                                                      'Flemish Region '
#                                                      '(Flanders), also known '
#                                                      'as Vlaams Gewest (Dutch '
#                                                      'long form), Vlaanderen '
#                                                      '(Dutch short form), '
#                                                      'Region Flamande (French '
#                                                      'long form), Flandre '
#                                                      '(French short form); '
#                                                      'Walloon Region '
#                                                      '(Wallonia), also known '
#                                                      'as Region Wallone '
#                                                      '(French long form), '
#                                                      'Wallonie (French short '
#                                                      'form), Waals Gewest '
#                                                      '(Dutch long form), '
#                                                      'Wallonie (Dutch short '
#                                                      'form)'},
#                 'Capital': {'daylight saving time': {...},
#                             'geographic coordinates': {...},
#                             'name': {...},
#                             'time difference': {...}},
#                 'Citizenship': {'citizenship by birth': {...},
#                                 'citizenship by descent only': {...},
#                                 'dual citizenship recognized': {...},
#                                 'residency requirement for naturalization': {'text': '5 '
#                                                                                      'years'}},
#                 'Constitution': {'amendments': {...}, 'history': {...}},
#                 'Country name': {'conventional long form': {...},
#                                  'conventional short form': {...},
#                                  'etymology': {...},
#                                  'local long form': {...},
#                                  'local short form': {...}},
#                 'Diplomatic representation from the US': {'FAX': {...},
#                                                           'chief of mission': {'text': 'Ambassador '
#                                                                                        'Denise '
#                                                                                        'Campbell '
#                                                                                        'BAUER '
#                                                                                        '(since '
#                                                                                        '26 '
#                                                                                        'September '
#                                                                                        '2013)'},
#                                                           'embassy': {...},
#                                                           'mailing address': {'text': 'PSC '
#                                                                                       '82, '
#                                                                                       'Box '
#                                                                                       '002, '
#                                                                                       'APO '
#                                                                                       'AE '
#                                                                                       '09710'},
#                                                           'telephone': {...}},
#                 'Diplomatic representation in the US': {'FAX': {...},
#                                                         'chancery': {...},
#                                                         'chief of mission': {'text': 'Ambassador '
#                                                                                      'Dirk '
#                                                                                      'Jozef '
#                                                                                      'M. '
#                                                                                      'WOUTERS '
#                                                                                      '(since '
#                                                                                      '16 '
#                                                                                      'September '
#                                                                                      '2016)'},
#                                                         'consulate(s) general': {'text': 'Atlanta, '
#                                                                                          'Los '
#                                                                                          'Angeles, '
#                                                                                          'New '
#                                                                                          'York'},
#                                                         'telephone': {...}},
#                 'Executive branch': {'cabinet': {...},
#                                      'chief of state': {...},
#                                      'elections/appointments': {...},
#                                      'head of government': {...}},
#                 'Flag description': {'text': 'three equal vertical bands of '
#                                              'black (hoist side), yellow, and '
#                                              'red; the vertical design was '
#                                              'based on the flag of France; the '
#                                              'colors are those of the arms of '
#                                              'the duchy of Brabant (yellow '
#                                              'lion with red claws and tongue '
#                                              'on a black field)'},
#                 'Government type': {'text': 'federal parliamentary democracy '
#                                             'under a constitutional monarchy'},
#                 'Independence': {'text': '4 October 1830 (a provisional '
#                                          'government declared independence '
#                                          'from the Netherlands); 21 July 1831 '
#                                          '(King LEOPOLD I ascended to the '
#                                          'throne)'},
#                 'International law organization participation': {'text': 'accepts '
#                                                                          'compulsory '
#                                                                          'ICJ '
#                                                                          'jurisdiction '
#                                                                          'with '
#                                                                          'reservations; '
#                                                                          'accepts '
#                                                                          'ICCt '
#                                                                          'jurisdiction'},
#                 'International organization participation': {'text': 'ADB '
#                                                                      '(nonregional '
#                                                                      'members), '
#                                                                      'AfDB '
#                                                                      '(nonregional '
#                                                                      'members), '
#                                                                      'Australia '
#                                                                      'Group, '
#                                                                      'Benelux, '
#                                                                      'BIS, CD, '
#                                                                      'CE, '
#                                                                      'CERN, '
#                                                                      'EAPC, '
#                                                                      'EBRD, '
#                                                                      'ECB, '
#                                                                      'EIB, '
#                                                                      'EITI '
#                                                                      '(implementing '
#                                                                      'country), '
#                                                                      'EMU, '
#                                                                      'ESA, EU, '
#                                                                      'FAO, '
#                                                                      'FATF, '
#                                                                      'G-9, '
#                                                                      'G-10, '
#                                                                      'IADB, '
#                                                                      'IAEA, '
#                                                                      'IBRD, '
#                                                                      'ICAO, '
#                                                                      'ICC '
#                                                                      '(national '
#                                                                      'committees), '
#                                                                      'ICCt, '
#                                                                      'ICRM, '
#                                                                      'IDA, '
#                                                                      'IEA, '
#                                                                      'IFAD, '
#                                                                      'IFC, '
#                                                                      'IFRCS, '
#                                                                      'IGAD '
#                                                                      '(partners), '
#                                                                      'IHO, '
#                                                                      'ILO, '
#                                                                      'IMF, '
#                                                                      'IMO, '
#                                                                      'IMSO, '
#                                                                      'Interpol, '
#                                                                      'IOC, '
#                                                                      'IOM, '
#                                                                      'IPU, '
#                                                                      'ISO, '
#                                                                      'ITSO, '
#                                                                      'ITU, '
#                                                                      'ITUC '
#                                                                      '(NGOs), '
#                                                                      'MIGA, '
#                                                                      'MONUSCO, '
#                                                                      'NATO, '
#                                                                      'NEA, '
#                                                                      'NSG, OAS '
#                                                                      '(observer), '
#                                                                      'OECD, '
#                                                                      'OIF, '
#                                                                      'OPCW, '
#                                                                      'OSCE, '
#                                                                      'Pacific '
#                                                                      'Alliance '
#                                                                      '(observer), '
#                                                                      'Paris '
#                                                                      'Club, '
#                                                                      'PCA, '
#                                                                      'Schengen '
#                                                                      'Convention, '
#                                                                      'SELEC '
#                                                                      '(observer), '
#                                                                      'UN, '
#                                                                      'UNCTAD, '
#                                                                      'UNESCO, '
#                                                                      'UNHCR, '
#                                                                      'UNIDO, '
#                                                                      'UNIFIL, '
#                                                                      'UNRWA, '
#                                                                      'UNTSO, '
#                                                                      'UPU, '
#                                                                      'WCO, '
#                                                                      'WHO, '
#                                                                      'WIPO, '
#                                                                      'WMO, '
#                                                                      'WTO, ZC'},
#                 'Judicial branch': {'highest court(s)': {...},
#                                     'judge selection and term of office': {...},
#                                     'subordinate courts': {...}},
#                 'Legal system': {'text': 'civil law system based on the French '
#                                          'Civil Code; note - Belgian law '
#                                          'continues to be modified in '
#                                          'conformance with the legislative '
#                                          'norms mandated by the European '
#                                          'Union; judicial review of '
#                                          'legislative acts'},
#                 'Legislative branch': {'description': {...},
#                                        'election results': {...},
#                                        'elections': {...},
#                                        'note': {...}},
#                 'National anthem': {'lyrics/music': {...},
#                                     'name': {...},
#                                     'note': {...}},
#                 'National holiday': {'text': '21 July (1831) Ascension Day '
#                                              '(ascension to the throne of King '
#                                              'LEOPOLD I)'},
#                 'National symbol(s)': {'text': 'lion; national colors: red, '
#                                                'black, yellow'},
#                 'Political parties and leaders': {'Flemish parties': {...},
#                                                   'Francophone parties': {...}},
#                 'Political pressure groups and leaders': {'other': {...},
#                                                           'text': 'Belgian '
#                                                                   'General '
#                                                                   'Federation '
#                                                                   'of Labor '
#                                                                   '[Rudy DE '
#                                                                   'LEEUW, Marc '
#                                                                   'GOBLET] ++ '
#                                                                   'Confederation '
#                                                                   'of Christan '
#                                                                   'Trade '
#                                                                   'Unions '
#                                                                   '[Marc '
#                                                                   'LEEMANS, '
#                                                                   'Marie-Helene '
#                                                                   'SKA] ++ '
#                                                                   'Federation '
#                                                                   'of '
#                                                                   'Enterprises '
#                                                                   'in Belgium '
#                                                                   '[Pieter '
#                                                                   'TIMMERMANS, '
#                                                                   'Michele '
#                                                                   'SIOEN]'},
#                 'Suffrage': {'text': '18 years of age; universal and '
#                                      'compulsory'}},
#  'Introduction': {'Background': {'text': 'Belgium became independent from the '
#                                          'Netherlands in 1830; it was occupied '
#                                          'by Germany during World Wars I and '
#                                          'II. The country prospered in the '
#                                          'past half century as a modern, '
#                                          'technologically advanced European '
#                                          'state and member of NATO and the EU. '
#                                          'Political divisions between the '
#                                          'Dutch-speaking Flemish of the north '
#                                          'and the French-speaking Walloons of '
#                                          'the south have led in recent years '
#                                          'to constitutional amendments '
#                                          'granting these regions formal '
#                                          'recognition and autonomy. Its '
#                                          'capital, Brussels, is home to '
#                                          'numerous international organizations '
#                                          'including the EU and NATO.'}},
#  'Military and Security': {'Military branches': {'text': 'Belgian Armed '
#                                                          'Forces: Land '
#                                                          'Operations Command, '
#                                                          'Naval Operations '
#                                                          'Command, Air '
#                                                          'Operations Command '
#                                                          '(2012)'},
#                            'Military expenditures': {'text': '0.85% of GDP '
#                                                              '(2016) ++ 0.91% '
#                                                              'of GDP (2015) ++ '
#                                                              '0.97% of GDP '
#                                                              '(2014) ++ 1.01% '
#                                                              'of GDP (2013) ++ '
#                                                              '1.05% of GDP '
#                                                              '(2012)'},
#                            'Military service age and obligation': {'text': '18 '
#                                                                            'years '
#                                                                            'of '
#                                                                            'age '
#                                                                            'for '
#                                                                            'male '
#                                                                            'and '
#                                                                            'female '
#                                                                            'voluntary '
#                                                                            'military '
#                                                                            'service; '
#                                                                            'conscription '
#                                                                            'abolished '
#                                                                            'in '
#                                                                            '1994 '
#                                                                            '(2012)'}},
#  'People and Society': {'Age structure': {'0-14 years': {...},
#                                           '15-24 years': {...},
#                                           '25-54 years': {...},
#                                           '55-64 years': {...},
#                                           '65 years and over': {...}},
#                         'Birth rate': {'text': '11.4 births/1,000 population '
#                                                '(2016 est.)'},
#                         'Contraceptive prevalence rate': {'note': {...},
#                                                           'text': '70.4%'},
#                         'Death rate': {'text': '9.7 deaths/1,000 population '
#                                                '(2016 est.)'},
#                         'Dependency ratios': {'elderly dependency ratio': {...},
#                                               'potential support ratio': {...},
#                                               'total dependency ratio': {...},
#                                               'youth dependency ratio': {...}},
#                         'Drinking water source': {'improved': {...},
#                                                   'unimproved': {...}},
#                         'Education expenditures': {'text': '6.4% of GDP '
#                                                            '(2011)'},
#                         'Ethnic groups': {'text': 'Flemish 58%, Walloon 31%, '
#                                                   'mixed or other 11%'},
#                         'HIV/AIDS - adult prevalence rate': {'text': 'NA'},
#                         'HIV/AIDS - deaths': {'text': 'NA'},
#                         'HIV/AIDS - people living with HIV/AIDS': {'text': 'NA'},
#                         'Health expenditures': {'text': '10.6% of GDP (2014)'},
#                         'Hospital bed density': {'text': '6.5 beds/1,000 '
#                                                          'population (2012)'},
#                         'Infant mortality rate': {'female': {...},
#                                                   'male': {...},
#                                                   'total': {...}},
#                         'Languages': {'text': 'Dutch (official) 60%, French '
#                                               '(official) 40%, German '
#                                               '(official) less than 1%'},
#                         'Life expectancy at birth': {'female': {...},
#                                                      'male': {...},
#                                                      'total population': {...}},
#                         'Major urban areas - population': {'text': 'BRUSSELS '
#                                                                    '(capital) '
#                                                                    '2.045 '
#                                                                    'million; '
#                                                                    'Antwerp '
#                                                                    '994,000 '
#                                                                    '(2015)'},
#                         'Maternal mortality rate': {'text': '7 deaths/100,000 '
#                                                             'live births (2015 '
#                                                             'est.)'},
#                         'Median age': {'female': {...},
#                                        'male': {...},
#                                        'total': {...}},
#                         "Mother's mean age at first birth": {'text': '28.2 '
#                                                                      '(2010 '
#                                                                      'est.)'},
#                         'Nationality': {'adjective': {...}, 'noun': {...}},
#                         'Net migration rate': {'text': '5.6 migrant(s)/1,000 '
#                                                        'population (2016 '
#                                                        'est.)'},
#                         'Obesity - adult prevalence rate': {'text': '22.1% '
#                                                                     '(2014)'},
#                         'Physicians density': {'text': '3.78 physicians/1,000 '
#                                                        'population (2010)'},
#                         'Population': {'text': '11,409,077 (July 2016 est.)'},
#                         'Population distribution': {'text': 'most of the '
#                                                             'population '
#                                                             'concentrated in '
#                                                             'the northern '
#                                                             'two-thirds of the '
#                                                             'country; the '
#                                                             'southeast is more '
#                                                             'thinly populated; '
#                                                             'considered to '
#                                                             'have one of the '
#                                                             'highest '
#                                                             'population '
#                                                             'densities in the '
#                                                             'world; '
#                                                             'approximately 97% '
#                                                             'live in urban '
#                                                             'areas'},
#                         'Population growth rate': {'text': '0.73% (2016 est.)'},
#                         'Religions': {'text': 'Roman Catholic 75%, other '
#                                               '(includes Protestant) 25%'},
#                         'Sanitation facility access': {'improved': {...},
#                                                        'unimproved': {...}},
#                         'School life expectancy (primary to tertiary education)': {'female': {'text': '21 '
#                                                                                                       'years '
#                                                                                                       '(2014)'},
#                                                                                    'male': {'text': '19 '
#                                                                                                     'years'},
#                                                                                    'total': {'text': '20 '
#                                                                                                      'years'}},
#                         'Sex ratio': {'0-14 years': {...},
#                                       '15-24 years': {...},
#                                       '25-54 years': {...},
#                                       '55-64 years': {...},
#                                       '65 years and over': {...},
#                                       'at birth': {...},
#                                       'total population': {...}},
#                         'Total fertility rate': {'text': '1.78 children '
#                                                          'born/woman (2016 '
#                                                          'est.)'},
#                         'Unemployment, youth ages 15-24': {'female': {...},
#                                                            'male': {...},
#                                                            'total': {...}},
#                         'Urbanization': {'rate of urbanization': {...},
#                                          'urban population': {...}}},
#  'Transnational Issues': {'Disputes - international': {'text': 'none'},
#                           'Illicit drugs': {'text': 'growing producer of '
#                                                     'synthetic drugs and '
#                                                     'cannabis; transit point '
#                                                     'for US-bound ecstasy; '
#                                                     'source of precursor '
#                                                     'chemicals for South '
#                                                     'American cocaine '
#                                                     'processors; transshipment '
#                                                     'point for cocaine, '
#                                                     'heroin, hashish, and '
#                                                     'marijuana entering '
#                                                     'Western Europe; despite a '
#                                                     'strengthening of '
#                                                     'legislation, the country '
#                                                     'remains vulnerable to '
#                                                     'money laundering related '
#                                                     'to narcotics, '
#                                                     'automobiles, alcohol, and '
#                                                     'tobacco; significant '
#                                                     'domestic consumption of '
#                                                     'ecstasy'},
#                           'Refugees and internally displaced persons': {'stateless persons': {'text': '5,776 '
#                                                                                                       '(2015)'}}},
#  'Transportation': {'Airports': {'text': '41 (2013)'},
#                     'Airports - with paved runways': {'1,524 to 2,437 m': {...},
#                                                       '2,438 to 3,047 m': {...},
#                                                       '914 to 1,523 m': {...},
#                                                       'over 3,047 m': {...},
#                                                       'total': {...},
#                                                       'under 914 m': {...}},
#                     'Airports - with unpaved runways': {'total': {...},
#                                                         'under 914 m': {...}},
#                     'Civil aircraft registration country code prefix': {'text': 'OO '
#                                                                                 '(2016)'},
#                     'Heliports': {'text': '1 (2013)'},
#                     'Merchant marine': {'by type': {...},
#                                         'foreign-owned': {...},
#                                         'registered in other countries': {...},
#                                         'total': {...}},
#                     'National air transport system': {'annual freight traffic on registered air carriers': {'text': '1,464,316,900 '
#                                                                                                                     'mt-km '
#                                                                                                                     '(2015)'},
#                                                       'annual passenger traffic on registered air carriers': {'text': '11,193,023'},
#                                                       'inventory of registered aircraft operated by air carriers': {'text': '117'},
#                                                       'number of registered air carriers': {'text': '7'}},
#                     'Pipelines': {'text': 'gas 3,139 km; oil 154 km; refined '
#                                           'products 535 km (2013)'},
#                     'Ports and terminals': {'LNG terminal(s) (import)': {...},
#                                             'container port(s) (TEUs)': {...},
#                                             'major seaport(s)': {...},
#                                             'river port(s)': {...}},
#                     'Railways': {'standard gauge': {...}, 'total': {...}},
#                     'Roadways': {'paved': {...},
#                                  'total': {...},
#                                  'unpaved': {...}},
#                     'Waterways': {'text': '2,043 km (1,528 km in regular '
#                                           'commercial use) (2012)'}}}

# %% [markdown]
# Ненужные подробности автоматически скрыты за «`...`», и мы видим самую суть. Френк, я в тебе не сомневался.

# %% [markdown]
# ## Чистый код: ratio и его упоротые друзья
#
# На днях мы использовали метод `SequenceMatcher.ratio()` из модуля `difflib`, чтобы оценить сходство двух строк.
#
# А что бы вы сказали, если узнали, что у того же `SequenceMatcher` есть ещё методы `quick_ratio()` и `real_quick_ratio()`? С описанием «возвращает верхнюю границу `ratio()` довольно быстро» и «возвращает верхнюю границу `ratio()` очень быстро»?
#
# Я бы сказал, что это говнокод. Если бы коллега принёс такой код на ревью, я бы предложил подумать ещё ツ Либо ты нормально называешь эти методы, чтобы понятно было, когда какой использовать. Либо прячешь их в глубине модуля и не делаешь частью публичного API.
#
# Конкретно в данном случае я бы сделал «быстрый» и «очень быстрый» методы приватными, потому что они нужны только для оптимизации работы других публичных методов `difflib`. Используются примерно так:

# %%
if matcher.real_quick_ratio() >= cutoff and \
    matcher.quick_ratio() >= cutoff and \
    matcher.ratio() >= cutoff:
    ...

# %% [markdown]
# Как вспомогательные методы — ладно. Но точно не в публичный интерфейс.
